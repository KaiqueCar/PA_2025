# %% [markdown]
# **Estou definindo as funções sem retorno**

# %% [markdown]
# E função com Parâmetro e sem Retorno

# %%
def soma(x,y):
  total = x + y
  print(total)


def diminuir(x,y):
  subi = x - y
  print(subi)

# %%
def apresentar(nome):
  print(f"Olá, {nome}! Prazer em te conhecer.")

# %%
nome = input("Digite seu nome: ")
apresentar(nome)
# Out:
# Digite seu nome: Kaique
# Olá, Kaique! Prazer em te conhecer.

# %%
def verificar_paridade(numero):
  if numero % 2 == 0:
   print(f" O numero {numero} é PAR")

  else:
   print(f" O numero {numero} é IMPAR:")

# %%
verificar_paridade(7)
verificar_paridade(12)
# Out:
#  O numero 7 é IMPAR:
#  O numero 12 é PAR

# %%
def boas_vindas(nome,curso):
  print(f"Olá, {nome}, seja bem-vindo ao curso de {curso}")

# %%
boas_vindas('Kaique', 'Python')
# Out:
# Olá, Kaique, seja bem-vindo ao curso de Python

# %% [markdown]
# Estou definindo funções com retorno

# %%
def multi(x,y):
  total = x * y
  return total

def divi(x,y):
  total = x/y
  return total

# %% [markdown]
# **Agora vou chamar essa funções**

# %%
valor1 = float(input("Digite o primeiro valor: "))
valor2 = float(input("Digite o segundo valor: "))

soma(valor1,valor2)
diminuir(valor1,valor2)
# Out:
# Digite o primeiro valor: 10
# Digite o segundo valor: 8
# 18.0
# 2.0

# %% [markdown]
# tipos de variaveis:
# local: é o tipo de variavel que só funciona dentro de uma função.
#
# Gloal: Variável normal, em que podemos retorna ao valor dela.

# %%
print(total)
print(subi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1323453876.py in <cell line: 0>()
# ----> 1 print(total)
#       2 print(subi)
#
# NameError: name 'total' is not defined

# %% [markdown]
# chamando uma função com retorno

# %%
valor1 = float(input("Digite o primeiro valor: "))
valor2 = float(input("Digite o segundo valor: "))

multiplicação = multi(valor1,valor2)
divisão = divi(valor1,valor2)

print('A multiplicação é: ', multiplicação)
print('A divisão é: ', divisão)
# Out:
# Digite o primeiro valor: 2
# Digite o segundo valor: 2
# A multiplicação é:  4.0
# A divisão é:  1.0

# %% [markdown]
# Tipo A: Função sem Parâmetro e sem Retorno

# %%
def saudacao():
  print("Olá! Seja bem-vindo(a) ao curso de Python!")

# %%
saudacao()
# Out:
# Olá! Seja bem-vindo(a) ao curso de Python!

# %%
from datetime import datetime

def mostrar_horario():
    agora = datetime.now()
    print(f"Horário atual: {agora.strftime('%H:%M:%S')}")

# %%
mostrar_horario()
# Out:
# Horário atual: 18:22:58

# %% [markdown]
# Tipo C: Função sem Parâmetro e com Retorno

# %%
def mensagem():
  return "Hoje é um ótimo dia para programar!"

# %%
print(mensagem())
# Out:
# Hoje é um ótimo dia para programar!

# %%
usar = mensagem()

print("Sexta-Feira" , usar)
# Out:
# Sexta-Feira Hoje é um ótimo dia para programar!

# %%
def somar():
  nota1 = float(input("Digite a nota1: "))
  nota2 = float(input("Digite a nota2: "))
  nota3 = float(input("Digite a nota3: "))
  total = nota1 + nota2 + nota3
  return total

# %%
somarnotas = somar()

print(f"A soma das notas é: {somarnotas}")
# Out:
# Digite a nota1: 5
# Digite a nota2: 5
# Digite a nota3: 5
# A soma das notas é: 15.0

# %%
def media(somarnotas):
  somarnotas/3
  return media

# %%
media()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1187343183.py in <cell line: 0>()
# ----> 1 media()
#
# TypeError: media() missing 1 required positional argument: 'somarnotas'

# %% [markdown]
# **Função com Parâmetro e com Retorno**

# %%
def calcular(preco, quantidade):
  total = preco*quantidade
  return total

valor = calcular(30,5)
print(valor)
# Out:
# 150

# %%
def cal_imc(peso,altura):
  imc = peso/(altura**2)
  return imc

peso = float(input("Digite seu peso: "))
altura = float(input("Digite seu altura: "))

immc = cal_imc(peso,altura)
print(immc)
# Out:
# Digite seu peso: 63
# Digite seu altura: 1.69
# 22.058051188683873

# %%
def  soma(a,b,c):
  soma = a + b + c
  media = soma/3
  return soma, media

# %% [markdown]
# # **Exercicios**

# %% [markdown]
# # QUESTÃO 1

# %%
def saudação():
  print("Bem vindo ao curso!")

saudação()
# Out:
# Bem vindo ao curso!

# %% [markdown]
# # QUESTÃO 2

# %%
def celcius_a_faren(ce):

  fa = ce * 9 / 5 + 32
  return fa
ce = float(input("Digite o grau, em celsius: "))
# Out:
# Digite o grau, em celsius: 30

# %%
conver = celcius_a_faren(ce)
print(f"A converção é: {conver}")
# Out:
# A converção é: 86.0

# %% [markdown]
# # QUESTÃO 3

# %%
def boas_vindas(nome):

  return nome
nome = input("Digite seu nome: ")
# Out:
# Digite seu nome: Kaique

# %%
nome1 = boas_vindas(nome)
print(f"Bem vindo, {nome1}")
# Out:
# Bem vindo, Kaique

# %% [markdown]
# # QUESTÃO 4

# %%
def  calcular_potencias(n):
  qua = n ** 2
  cu = n ** 3
  return qua, cu

# %%
resul = calcular_potencias(4)
print(resul)
# Out:
# (16, 64)

# %% [markdown]
# # QUESTÃO 5

# %%
def conta(n):

  while n>0:
    print(n)
    n -=1

# %%
conta(6)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# # QUESTÃO 6

# %%
def calcular_desconto(valor,desconto):
  desconto2= valor * desconto / 100
  valorFinal = valor - desconto2

  return valorFinal

# %%
valor = float(input("Digite o valor do produto: "))
desconto = float(input("Digite o desconto: "))
# Out:
# Digite o valor do produto: 100
# Digite o desconto: 9

# %%
pagar = valor
promoção = desconto
valorFinal2 = calcular_desconto(valor,desconto)

print(f"Seu produto com o valor de: {pagar}, recebeu um desconto de: {promoção}%. Parabéns, pagará só: {valorFinal2} ")
# Out:
# Seu produto com o valor de: 100.0, recebeu um desconto de: 9.0%. Parabéns, pagará só: 91.0

# %% [markdown]
# # QUESTÃO 7

# %%
def encontrar_extremos():
  lis = [1,2,3,4,5,6,7,8]
  maxi = max(lis)
  mini = min(lis)
  return maxi, mini

# %%
valores = encontrar_extremos()

print(f"O maior e menor valores dessa lista são: {valores}")
# Out:
# O maior e menor valores dessa lista são: (8, 1)

# %% [markdown]
# # QUESTÃO 8

# %%
def calculadora(a,b):
  if (nume == 1):
   soma = a + b
   print(soma)

  if (nume == 2):
   sub = a - b
   print(sub)

  if (nume == 3):
     divi = a / b
     print(divi)


  if (nume == 4):
    multi = a*b
    print(multi)

# %%
a = float(input("Digite o valor de 'a': "))
b = float(input("Digite o valor de 'b': "))
nume = float(input("Digite '1' para somar, '2' para subtrair, '3' para dividir e '4' para multilicar!: "))

if nume == 1:
  print("Seu reultado é:")
  calculadora(a,b)

if nume == 2:
  print("Seu reultado é:")
  calculadora(a,b)

if (nume == 3):
 if a != 0 and b != 0:
  print("Seu reultado é:")
  calculadora(a,b)
 else:
    print("O valor de 'a' e 'b' não podem ser igual a '0'! ")

if nume == 4:
  print("Seu reultado é:")
  calculadora(a,b)
# Out:
# Digite o valor de 'a': 205
# Digite o valor de 'b': 340
# Digite '1' para somar, '2' para subtrair, '3' para dividir e '4' para multilicar!: 2
# Seu reultado é:
# -135.0

# %% [markdown]
# # QUESTÃO 9

# %%
def enviar_email(destinatario, assunto, corpo='*Esse é um email automático*'):
  print(f"{corpo}\n Email para: {destinatario}, com a seguinte mensagem: {assunto}")

# %%
destinatario = str(input("Digite para quem você quer enviar sua mensagem: "))
assunto = str(input("Digite a mensagem que você quer envir: "))
corpo = '*Esse é um email automático*'

print(f"{corpo}\n Email para: {destinatario}, com a seguinte mensagem: {assunto}")
# Out:
# Digite para quem você quer enviar sua mensagem: kaique@1234
# Digite a mensagem que você quer envir: Você precisa melhorar em Python!
# *Esse é um email automático*
#  Email para: kaique@1234, com a seguinte mensagem: Você precisa melhorar em Python!

# %% [markdown]
# ## QUESTÃO 10

# %%
def avaliar_aluno(nota):
    if nota >= 7:
        return "Aprovado"
    elif nota >= 5:
        return "Recuperação"
    else:
        return "Reprovado"

print(avaliar_aluno(8.5))
print(avaliar_aluno(6.0))
print(avaliar_aluno(4.5))
# Out:
# Aprovado
# Recuperação
# Reprovado
